# %%
###!pip install numpy==1.19.0

# %%
###numpy stands for numerical python va omdeye moredi ke mikhad roosh kar kone arraye hast pas numpy az data structure arraye estefadeh mikone
###numpy baraye ma in mavared ro khoob support mikone : 1-jabre khati 2-tabdile fourier 3-mabahese matris ro ham khoob support nemikone

# %%
###chera aslan az arraye va numpy estefadeh mikonim ????

#ma kheyli dar morede list ha sohbat kardim va midoonim list ha data structure e hastand ke kheyli shabihe arraye ha hastand faghat farghi ke daran ine ke anaseri ke dakheleshoon gharar migire
#mitoone na hamgen bashe mesle zir ke ham adad darin ham string va ham va ...
list = ['a', 1, 2, 'Ali']
#va in list mire yek jayi az memory gharar migire va barname e ke man minevisam mire in data structure ro az memory bar midare va bahash yek seri kara anjam mide

##dar noghteye moghabele list , arraye vojood dare ke mige shoma mitooni faghat yek noe dtatype dashte bashi ya yek jens data dakhelesh dashte bashi yani hamgen hast masalan ya bayad hameye anasere
#arraye adad bashe ya string ya  ...

array = [1, 2, 3, 4]

#va in arraye ham mire yek jayi az memory gharar migire va barname e ke man minevisam mire in data structure ro az memory bar midare va bahash yek seri kara anjam mide


#########hala soal ine ke vaghti list be in khoobi hast va na hamgen ham hast pas arraye in vasat be che dardi mikhore va numpy in vasart chi mige ????

#javab1 : bahs sare data haye kheyli bozorg hast va data hayi ke ML bahash kar mikone , pas tooye data haye koochak list behemoon kheyli khoob javab mide vali dar morede data haye bozorg arraye
#behemoon komak mikone

#javab2 : numpy oomade az az data structure arraye estefadeh mikone va yek seri karayi baramoon anjam mide va az yek seri function hayi estefadeh mikone ke kar ro baramoon besyar sadeh mikone be
#khosoos dar hajme bala masalan age data yi dar hade MB ya KB dashte basham (ke dara data science kheyli estefadeh mishe va mamoolan dataset ham ba in hajm hast) ,ba numpy kheyli khoob mitoonam
#in ro handle konam

# %%
###khasiat hamgen(homogeneous) boodane numpy array be in shekl hast:
#yani age man behesh yek vector bedam ke ham shamele integer bashe va ham shamele string bashe khode numpy array hame ro be string tabdil mikone
import numpy as np
n = np.array([1, 2, 'c'])
n
# Out:
# array(['1', '2', 'c'], dtype='<U21')

# %%
###############list vs numpy array
#az 2 manzar inaro moghayese mikonam : 1-fazaye masrafi dar hafeze 2-sorate ejra

#baraye shoroo far konid ke ye bordar ya vector be shekle zir darim va yek bar behesh barchasbe list midim va yekbar behesh barchasbe numpy array yani yekbar az didgahe list behesh negah mikonam va
#yek bar az didgahe numpy array

vector = [1, 2, 3]
#baraye didane moghayeseye in 2 edame ro dar file word tozih dadam ba shekl

# %%
n = 100000
lst_size = 64 + 8*n + 28*n
narray_size = 96 + 4*n

# %%
lst_size
# Out:
# 3600064

# %%
narray_size
# Out:
# 800096

# %%
3600064 / 400096
# Out:
# 8.998000479884828

# %%
n = 100000
lst_size = 64 + 8*n + 28*n
narray_size = 96 + 8*n

# %%
lst_size
# Out:
# 3600064

# %%
narray_size
# Out:
# 800096

# %%
3600064 / 800096
# Out:
# 4.499540055193377
